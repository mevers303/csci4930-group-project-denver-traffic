# %% [markdown]
# # EDA

# %%
import pandas as pd

# load from csv
df = pd.read_csv("data/processed_crime_traffic_accidents.csv")

# force all columns to be strings (except the target variable)
for col in df.columns:
    if col != "high_risk":
        df[col] = df[col].astype(str)

# list columns
list(df.columns)
# Out:
# ['offense_code',
#  'district_id',
#  'precinct_id',
#  'neighborhood_id',
#  'bicycle_ind',
#  'pedestrian_ind',
#  'HARMFUL_EVENT_SEQ_1',
#  'HARMFUL_EVENT_SEQ_2',
#  'HARMFUL_EVENT_SEQ_3',
#  'road_location',
#  'ROAD_DESCRIPTION',
#  'ROAD_CONTOUR',
#  'ROAD_CONDITION',
#  'LIGHT_CONDITION',
#  'TU1_VEHICLE_TYPE',
#  'TU1_TRAVEL_DIRECTION',
#  'TU1_VEHICLE_MOVEMENT',
#  'TU1_DRIVER_ACTION',
#  'TU1_DRIVER_HUMANCONTRIBFACTOR',
#  'TU1_PEDESTRIAN_ACTION',
#  'TU2_VEHICLE_TYPE',
#  'TU2_TRAVEL_DIRECTION',
#  'TU2_VEHICLE_MOVEMENT',
#  'TU2_DRIVER_ACTION',
#  'TU2_DRIVER_HUMANCONTRIBFACTOR',
#  'TU2_PEDESTRIAN_ACTION',
#  'high_risk',
#  'hour',
#  'day_of_week',
#  'month']

# %%
df['offense_code'].value_counts()
# Out:
# offense_code
# 5441    189834
# 5401     84899
# 5420      7511
# Name: count, dtype: int64

# %%
df['district_id'].value_counts()
# Out:
# district_id
# 3     67276
# 1     48574
# 2     34680
# 6     33498
# 5     30855
# 4     27525
# 7      4428
# UI      155
# 9        30
# G        18
# J        13
# 8         6
# 10        6
# U         2
# 11        1
# Name: count, dtype: int64

# %%
df['precinct_id'].value_counts()
# Out:
# precinct_id
# 311.0    17010
# 312.0    14129
# 123.0    13268
# 324.0    10067
# 611.0    10018
# 313.0     9894
# 512.0     9734
# 113.0     8869
# 122.0     8408
# 511.0     8315
# 412.0     8285
# 112.0     7809
# 111.0     7781
# 323.0     7719
# 623.0     7658
# 213.0     7610
# 322.0     7548
# 612.0     7455
# 212.0     7309
# 221.0     6501
# 421.0     6459
# 321.0     6417
# 622.0     6266
# 621.0     6186
# 222.0     5770
# 121.0     5717
# 411.0     5674
# 211.0     5657
# 522.0     5646
# 423.0     5505
# 223.0     5416
# 314.0     5215
# 521.0     5192
# 422.0     5053
# 759.0     3359
# 523.0     2159
# Name: count, dtype: int64

# %%
df['neighborhood_id'].value_counts()
# Out:
# neighborhood_id
# Central Park     15645
# Baker            12654
# Five Points       9475
# Lincoln Park      8331
# Hampden South     7859
#                  ...
# Fort Logan         941
# Country Club       871
# Kennedy            712
# Wellshire          304
# Indian Creek       258
# Name: count, Length: 78, dtype: int64

# %%
df['bicycle_ind'].value_counts()
# Out:
# bicycle_ind
# 0    278882
# 1      3362
# Name: count, dtype: int64

# %%
df['pedestrian_ind'].value_counts()
# Out:
# pedestrian_ind
# 0    275919
# 1      6325
# Name: count, dtype: int64

# %%
df['HARMFUL_EVENT_SEQ_1'].value_counts()
# Out:
# HARMFUL_EVENT_SEQ_1
# FRONT TO REAR WITH MV IN TRANSPORT                  68433
# FRONT TO SIDE WITH MV IN TRANSPORT                  43476
# SIDE TO SIDE SAME DIRECTION WITH MV IN TRANSPORT    31972
# Front to Rear                                       24042
# Front to Side                                       20056
#                                                     ...
# Mailbox                                                13
# Railroad Crossing Equipment                             9
# Overhead Structure (Bridge)                             6
# School Age To/From School                               4
# Immersion, Full or Partial                              1
# Name: count, Length: 86, dtype: int64

# %%
df['HARMFUL_EVENT_SEQ_2'].value_counts()
# Out:
# HARMFUL_EVENT_SEQ_2
# FRONT TO REAR WITH MV IN TRANSPORT                  14366
# Front to Rear                                        4819
# FRONT TO SIDE WITH MV IN TRANSPORT                   4474
# SIDE TO SIDE SAME DIRECTION WITH MV IN TRANSPORT     3743
# PARKED MV WITH OTHER VEHICLE                         2746
#                                                     ...
# Domestic Animal                                         3
# School Age To/From School                               2
# Overhead Structure (Bridge)                             2
# RAILROAD CROSSING EQUIPMENT                             2
# Immersion, Full or Partial                              1
# Name: count, Length: 85, dtype: int64

# %%
df['HARMFUL_EVENT_SEQ_3'].value_counts()
# Out:
# HARMFUL_EVENT_SEQ_3
# FRONT TO REAR WITH MV IN TRANSPORT                  65277
# FRONT TO SIDE WITH MV IN TRANSPORT                  41389
# SIDE TO SIDE SAME DIRECTION WITH MV IN TRANSPORT    30005
# Front to Rear                                       23475
# Front to Side                                       19261
#                                                     ...
# Railroad Crossing Equipment                            11
# Mailbox                                                10
# Overhead Structure (Bridge)                             6
# School Age To/From School                               5
# Immersion, Full or Partial                              3
# Name: count, Length: 86, dtype: int64

# %%
df['road_location'].value_counts()
# Out:
# road_location
# ON ROADWAY                                           173261
# On Roadway                                            64261
# ON PRIVATE PROPERTY                                   15595
# On Private Property                                    7460
# RAN OFF RIGHT SIDE                                     4264
# RAN OFF LEFT SIDE                                      2371
# Ran Off Right Side                                     2133
# UNDER INVESTIGATION                                    1540
# Ran Off Left Side                                       900
# VEHICLE CROSSED CENTER MEDIAN INTO OPPOSING LANES       425
# Center Median/Island                                    330
# RAN OFF 'T' INTERSECTION                                268
# Ran Off 'T' Intersection                                144
# Vehicle Crossed Center Median Into Opposing Lanes       131
# Name: count, dtype: int64

# %%
df['ROAD_DESCRIPTION'].value_counts()
# Out:
# ROAD_DESCRIPTION
# NON INTERSECTION            82144
# AT INTERSECTION             62726
# Non-Intersection            33405
# At Intersection             26150
# INTERSECTION RELATED        18127
# PARKING LOT                 14410
# HIGHWAY INTERCHANGE         10604
# Parking Lot                  6944
# Intersection Related         6765
# DRIVEWAY ACCESS RELATED      5634
# ALLEY RELATED                2388
# UNDER INVESTIGATION          1540
# Driveway Access Related      1201
# Ramp Related                 1116
# Ramp                         1044
# Alley Related                 677
# ROUNDABOUT                    635
# Express/Managed/HOV Lane      260
# Roundabout                    183
# Mid-Block Crosswalk           154
# Crossover-Related              97
# Auxiliary Lane                 74
# Share-Use Path or Trail        29
# Name: count, dtype: int64

# %%
df['ROAD_CONTOUR'].value_counts()
# Out:
# ROAD_CONTOUR
# STRAIGHT ON-LEVEL           159028
# Straight - Level             64766
# STRAIGHT ON-GRADE            27216
# CURVE ON-LEVEL                5799
# CURVE ON-GRADE                4005
# Straight - Downhill           2899
# Straight - Uphill             2254
# Curve Right - Level           1802
# Curve Left - Level            1541
# UNDER INVESTIGATION           1540
# HILLCREST                      530
# Unknown - Level                380
# Curve Right - Downhill         354
# Curve Right - Uphill           315
# Curve Left - Downhill          305
# Unknown                        304
# Curve Left - Uphill            253
# Straight - Hill Crest          221
# Straight - Unknown             211
# Straight - Sag/Bottom           48
# Curve Left - Hill Crest         31
# Curve Right - Unknown           26
# Curve Right - Hill Crest        19
# Curve Left - Unknown            17
# Unknown - Downhill              16
# Unknown - Uphill                11
# ...

# %%
df['ROAD_CONDITION'].value_counts()
# Out:
# ROAD_CONDITION
# DRY                                       169737
# Dry                                        70301
# WET                                        13083
# ICY                                         6282
# SNOWY                                       4852
# Wet                                         3379
# Icy                                         1606
# UNDER INVESTIGATION                         1540
# SLUSHY                                      1229
# Snowy                                       1050
# Slushy                                       416
# SNOWY WITH VISIBLE ICY ROAD TREATMENT        362
# Dry W/Visible Icy Road Treatment             330
# Icy W/Visible Icy Road Treatment             262
# Snowy W/Visible Icy Road Treatment           256
# WET WITH VISIBLE ICY ROAD TREATMENT          236
# DRY WITH VISIBLE ICY ROAD TREATMENT          232
# SLUSHY WITH VISIBLE ICY ROAD TREATMENT       178
# ICY WITH VISIBLE ICY ROAD TREATMENT          166
# ...

# %%
df['LIGHT_CONDITION'].value_counts()
# Out:
# LIGHT_CONDITION
# DAY LIGHT              138562
# Daylight                53307
# DARK-LIGHTED            44846
# Dark-Lighted            19996
# DAWN OR DUSK             8289
# DARK-UNLIGHTED           4346
# Dawn or Dusk             2566
# Dark-Unlighted           2150
# UNDER INVESTIGATION      1540
# Name: count, dtype: int64

# %%
df['TU1_VEHICLE_TYPE'].value_counts()
# Out:
# TU1_VEHICLE_TYPE
# PASSENGER CAR/VAN                                                    96849
# SUV                                                                  59415
# Passenger Car/Passenger Van                                          34845
# PICKUP TRUCK/UTILITY VAN                                             21641
# HIT AND RUN UNKNOWN                                                  14703
# Pickup Truck/Utility Van                                              9839
# OTHER                                                                 8117
# Unknown (Hit and Run Only)                                            6576
# VEHICLE OVER 10000 LBS                                                6324
# PICKUP TRUCK/UTILITY VAN WITH TRAILIER                                4680
# MOTORCYCLE                                                            1909
# UNDER INVESTIGATION                                                   1540
# ...

# %%
df['TU1_TRAVEL_DIRECTION'].value_counts()
# Out:
# TU1_TRAVEL_DIRECTION
# NORTH                  52023
# SOUTH                  46790
# WEST                   40570
# EAST                   40294
# North                  18131
# South                  16548
# East                   14472
# West                   14252
# OTHER                   6515
# NORTHWEST               3901
# SOUTHEAST               3692
# SOUTHWEST               3125
# NORTHEAST               2987
# UNDER INVESTIGATION     1540
# Northwest               1248
# Southeast               1143
# Northeast                979
# Southwest                923
# Name: count, dtype: int64

# %%
df['TU1_VEHICLE_MOVEMENT'].value_counts()
# Out:
# TU1_VEHICLE_MOVEMENT
# GOING STRAIGHT                      103081
# Going Straight                       36306
# MAKING LEFT TURN                     23877
# CHANGING LANES                       16162
# OTHER                                14185
# BACKING                              11042
# MAKING RIGHT TURN                     9115
# Making Left Turn                      8374
# Changing Lanes                        5746
# ENTERING/LEAVING PARKED POSITION      5606
# SLOWING                               5586
# Backing                               3861
# Making Right Turn                     3237
# SPUN OUT OF CONTROL                   2526
# WEAVING                               2431
# Entering/Leaving Parked Position      1870
# Slowing                               1863
# STOPPED IN TRAFFIC                    1716
# UNDER INVESTIGATION                   1540
# Other (Describe in Narrative)         1514
# MAKING U-TURN                         1471
# ...

# %%
df['TU1_DRIVER_ACTION'].value_counts()
# Out:
# TU1_DRIVER_ACTION
# CARELESS DRIVING                          41447
# FOLLOWED TOO CLOSELY                      29812
# OTHER                                     22237
# FAILED TO YIELD ROW                       19539
# Careless Driving                          18910
# LANE VIOLATION                            14862
# Followed Too Closely                      11028
# Failed to Yield ROW                        8230
# FAILED TO STOP AT SIGNAL                   7345
# WEAVING                                    6862
# Lane Violation                             6712
# No Action                                  6319
# IMPROPER BACKING                           6139
# No Contributing Action                     5085
# STOPPED IN TRAFFIC                         4487
# EXCEED SAFE/POSTED SPEED                   3886
# Failed to Stop at Signal                   3506
# PARKED                                     3302
# RECKLESS DRIVING                           2796
# ...

# %%
df['TU1_DRIVER_HUMANCONTRIBFACTOR'].value_counts()
# Out:
# TU1_DRIVER_HUMANCONTRIBFACTOR
# No Apparent Contributing Factor            94775
# OTHER                                      37676
# AGGRESSIVE DRIVING                         18529
# DISTRACTED-OTHER                           16724
# DRIVER INEXPERIENCE                        13704
# Not Observed                               12832
# DUI/DWAI/DUID                              10713
# Looked/Did Not See                          8418
# DRIVER UNFAMILIAR WITH AREA                 7293
# Aggressive Driving                          5409
# Distracted/Other Interior                   4412
# Other Factor                                4126
# DISTRACTED CELLPHONE                        2815
# Driver Inexperience                         2299
# Distracted/Other Exterior                   2145
# Age/Driver Ability                          1824
# Driver Unfamiliar With Area                 1782
# DISTRACTED PASSENGER                        1616
# ...

# %%
df['TU1_PEDESTRIAN_ACTION'].value_counts()
# Out:
# TU1_PEDESTRIAN_ACTION
# OTHER                                                                      127464
# UNDER INVESTIGATION                                                          1540
# CROSS/ENTER NOT AT INTERSECTION                                               632
# CROSS AGAINST SIGNAL                                                          444
# Failure to Obey Traffic Signs, Signals, or Officer                            266
# CROSS/ENTER AT INTERSECTION                                                   225
# Cross/Enter NOT at Intersection                                               197
# Cross/Enter at Intersection                                                   157
# Other (Describe in Narrative)                                                 151
# Failure to Yield Right-Of-Way                                                 117
# Dart/Dash                                                                      85
# ...

# %%
df['TU2_VEHICLE_TYPE'].value_counts()
# Out:
# TU2_VEHICLE_TYPE
# PASSENGER CAR/VAN                                                    97377
# SUV                                                                  64393
# Passenger Car/Passenger Van                                          37351
# PICKUP TRUCK/UTILITY VAN                                             19363
# OTHER                                                                16268
# Pickup Truck/Utility Van                                              8775
# VEHICLE OVER 10000 LBS                                                4630
# PICKUP TRUCK/UTILITY VAN WITH TRAILIER                                3866
# MOTORCYCLE                                                            1917
# UNDER INVESTIGATION                                                   1540
# BICYCLE                                                               1319
# TRANSIT BUS                                                           1229
# ...

# %%
df['TU2_TRAVEL_DIRECTION'].value_counts()
# Out:
# TU2_TRAVEL_DIRECTION
# NORTH                  47719
# SOUTH                  42048
# WEST                   37889
# EAST                   37611
# North                  18277
# OTHER                  17933
# South                  16090
# East                   14548
# West                   14471
# NORTHWEST               2389
# SOUTHEAST               2214
# SOUTHWEST               1814
# NORTHEAST               1730
# UNDER INVESTIGATION     1540
# Northwest                769
# Southeast                648
# Northeast                600
# Southwest                574
# Name: count, dtype: int64

# %%
df['TU2_VEHICLE_MOVEMENT'].value_counts()
# Out:
# TU2_VEHICLE_MOVEMENT
# GOING STRAIGHT                      81076
# STOPPED IN TRAFFIC                  40454
# Going Straight                      32256
# PARKED                              29442
# OTHER                               16511
# Parked                              13169
# Stopped in Traffic                  13041
# SLOWING                             11951
# MAKING LEFT TURN                     6888
# MAKING RIGHT TURN                    3514
# Slowing                              3320
# Making Left Turn                     2917
# UNDER INVESTIGATION                  1540
# CHANGING LANES                       1495
# Making Right Turn                    1170
# BACKING                               581
# ENTERING/LEAVING PARKED POSITION      519
# Changing Lanes                        497
# Other (Describe in Narrative)         451
# Backing                               236
# Entering Traffic Way/Merge            234
# Negotiating a Curve                   205
# ...

# %%
df['TU2_DRIVER_ACTION'].value_counts()
# Out:
# TU2_DRIVER_ACTION
# OTHER                                     91557
# No Action                                 63213
# No Contributing Action                    61292
# UNDER INVESTIGATION                        1540
# LANE VIOLATION                              856
# Other Contributing Action                   818
# FOLLOWED TOO CLOSELY                        770
# EXCEED SAFE/POSTED SPEED                    625
# CARELESS DRIVING                            610
# FAILED TO YIELD ROW                         396
# Careless Driving                            262
# Lane Violation                              248
# FAILED TO STOP AT SIGNAL                    213
# Followed Too Closely                        205
# Failed to Yield ROW                         150
# IMPROPER BACKING                            118
# IMPEDED TRAFFIC                             104
# IMPROPER TURN                                92
# Failed to Stop at Signal                     80
# ...

# %%
df['TU2_DRIVER_HUMANCONTRIBFACTOR'].value_counts()
# Out:
# TU2_DRIVER_HUMANCONTRIBFACTOR
# NO APPARENT                                158553
# No Apparent Contributing Factor             60290
# OTHER                                       26086
# Not Observed                                 2778
# UNDER INVESTIGATION                          1540
# AGGRESSIVE DRIVING                            720
# Other Factor                                  500
# DRIVER INEXPERIENCE                           455
# Looked/Did Not See                            352
# DISTRACTED-OTHER                              324
# Aggressive Driving                            190
# DUI/DWAI/DUID                                 186
# DRIVER UNFAMILIAR WITH AREA                   171
# ASLEEP AT THE WHEEL                            83
# Age/Driver Ability                             77
# Driver Inexperience                            70
# Distracted/Other Exterior                      47
# Driver Unfamiliar With Area                    44
# ...

# %%
df['TU2_PEDESTRIAN_ACTION'].value_counts()
# Out:
# TU2_PEDESTRIAN_ACTION
# OTHER                                                                      126836
# UNDER INVESTIGATION                                                          1540
# CROSS/ENTER AT INTERSECTION                                                   969
# No Contributing Action                                                        967
# Cross/Enter at Intersection                                                   619
# Other (Describe in Narrative)                                                 150
# CROSS/ENTER NOT AT INTERSECTION                                               148
# STANDING IN ROADWAY                                                           103
# Cross/Enter NOT at Intersection                                                87
# CROSS AGAINST SIGNAL                                                           59
# ENTERING/EXITING VEHICLE                                                       55
# ...

# %%
df['high_risk'].value_counts()
# Out:
# high_risk
# 0    275685
# 1      6559
# Name: count, dtype: int64

# %%
df['hour'].value_counts()
# Out:
# hour
# 17    21285
# 16    21187
# 15    21056
# 14    18006
# 12    17629
# 8     17286
# 13    17207
# 18    15757
# 7     15630
# 11    15571
# 9     13774
# 10    13562
# 19    10572
# 21     8772
# 20     8725
# 22     8154
# 6      7958
# 23     6501
# 2      5401
# 0      5203
# 1      4788
# 5      3401
# 3      2656
# 4      2163
# Name: count, dtype: int64

# %%
df['day_of_week'].value_counts()
# Out:
# day_of_week
# 4    46317
# 3    44621
# 2    43630
# 1    43210
# 0    40056
# 5    34513
# 6    29897
# Name: count, dtype: int64

# %%
df['month'].value_counts()
# Out:
# month
# 10    25996
# 9     24777
# 8     24570
# 1     24429
# 7     23462
# 5     23357
# 6     23208
# 2     23124
# 11    23030
# 12    22918
# 3     22003
# 4     21370
# Name: count, dtype: int64
